# %% [markdown]
# ### Recursion

# %% [markdown]
# ![image.png](attachment:5cb9b94d-1fb8-4b65-b073-59e88e4b37e4.png)

# %%
### just a trial:
def Factorial(n):

    while n > 0:
        return n*(n-1)
        n -= 1
Factorial(4)
# Out:
# 12

# %% [markdown]
# Lmao epic fail

# %% [markdown]
# In recursion we have a base case that helps us stop the endless iteration.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n*factorial(n-1)

factorial(10)
# Out:
# 3628800

# %%
# English Ruler
class EnglishRuler: # first step
    def __init__(self,num_inches, major_length):
        self.num_inches = num_inches
        self.major_length = major_length

    def draw_line(self,tick_length, tick_label=''): #2nd step
        line = '-'*tick_length
        if tick_label:
            line += ' '+tick_label
        print(line)

    def draw_interval(self, center_length): #4th step
        if center_length>0:
            self.draw_interval(center_length - 1)
            self.draw_line(center_length)
            self.draw_interval(center_length-1)

    def draw_ruler(self): #3rd step
        self.draw_line(self.major_length,'0')
        for j in range(1,self.num_inches + 1):
            self.draw_interval(self.major_length-1)
            self.draw_line(self.major_length, str(j))
        
        

ruler = EnglishRuler(1,5)
ruler.draw_ruler()
# Out:
# ----- 0
# -
# --
# -
# ---
# -
# --
# -
# ----
# -
# --
# -
# ---
# -
# --
# -
# ----- 1

# %%
def factoral(n):
    if n == 0:
        return 1
    else:
        print(n * factoral(n-1))
        return n * factoral(n-1)

factoral(4)
# Out:
# 1
# 2
# 1
# 6
# 1
# 2
# 1
# 24
# 1
# 2
# 1
# 6
# 1
# 2
# 1
# 24

# %%
def linewithlabel(line_thick):#, line_label = ''):
    line = '-' * line_thick
    print(line)

linewithlabel(4)
# Out:
# ----

# %%
# lets add a label that the end:
def linewithlabe(line_thick, line_label = ''):
    line = '-'* line_thick
    while True:
        line += ' ' + line_label
        break
    print(line)


linewithlabe(4, 'Abraham')
# Out:
# ---- Abraham

# %%
# binary search

# %%
def reverser(data):
    data[]
